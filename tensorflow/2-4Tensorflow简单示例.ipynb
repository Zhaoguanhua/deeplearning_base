# %%
import tensorflow as tf
import numpy as np

# %%
#使用numpy随机生成100个随机点
x_data=np.random.rand(100)
y_data=x_data*1+0.2

#构造线性模型
b=tf.Variable(0.)
k=tf.Variable(0.)
y=k*x_data+b

#二次代价函数
loss=tf.reduce_mean(tf.square(y_data-y))
#定义梯度下降法来进行训练大的优化器
optimizer=tf.train.GradientDescentOptimizer(0.2)
#定义最小化代价函数
train=optimizer.minimize(loss)

#初始化变量
init=tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    for step in range(2001):
        sess.run(train)
        if step%20==0:
            print(step,sess.run([k,b]))
# Out:
# 0 [0.15573074, 0.267294]
# 20 [0.57455885, 0.41236302]
# 40 [0.7424439, 0.32856187]
# 60 [0.8440791, 0.27782962]
# 80 [0.9056077, 0.24711691]
# 100 [0.94285625, 0.22852392]
# 120 [0.96540594, 0.217268]
# 140 [0.9790572, 0.21045384]
# 160 [0.9873215, 0.20632862]
# 180 [0.9923246, 0.20383124]
# 200 [0.99535334, 0.20231943]
# 220 [0.99718696, 0.20140415]
# 240 [0.9982971, 0.20085004]
# 260 [0.998969, 0.20051461]
# 280 [0.99937594, 0.20031151]
# 300 [0.9996222, 0.20018858]
# 320 [0.9997713, 0.20011418]
# 340 [0.9998616, 0.2000691]
# 360 [0.9999163, 0.2000418]
# 380 [0.99994934, 0.2000253]
# 400 [0.99996936, 0.20001528]
# 420 [0.9999814, 0.20000929]
# 440 [0.9999887, 0.20000567]
# 460 [0.9999931, 0.20000345]
# 480 [0.99999577, 0.20000212]
# 500 [0.9999973, 0.20000133]
# 520 [0.9999985, 0.20000076]
# 540 [0.9999989, 0.20000052]
# 560 [0.9999989, 0.20000052]
# 580 [0.9999989, 0.20000052]
# 600 [0.9999989, 0.20000052]
# 620 [0.9999989, 0.20000052]
# 640 [0.9999989, 0.20000052]
# 660 [0.9999989, 0.20000052]
# 680 [0.9999989, 0.20000052]
# 700 [0.9999989, 0.20000052]
# 720 [0.9999989, 0.20000052]
# 740 [0.9999989, 0.20000052]
# 760 [0.9999989, 0.20000052]
# 780 [0.9999989, 0.20000052]
# 800 [0.9999989, 0.20000052]
# 820 [0.9999989, 0.20000052]
# 840 [0.9999989, 0.20000052]
# 860 [0.9999989, 0.20000052]
# 880 [0.9999989, 0.20000052]
# 900 [0.9999989, 0.20000052]
# 920 [0.9999989, 0.20000052]
# 940 [0.9999989, 0.20000052]
# 960 [0.9999989, 0.20000052]
# 980 [0.9999989, 0.20000052]
# 1000 [0.9999989, 0.20000052]
# 1020 [0.9999989, 0.20000052]
# 1040 [0.9999989, 0.20000052]
# 1060 [0.9999989, 0.20000052]
# 1080 [0.9999989, 0.20000052]
# 1100 [0.9999989, 0.20000052]
# 1120 [0.9999989, 0.20000052]
# 1140 [0.9999989, 0.20000052]
# 1160 [0.9999989, 0.20000052]
# 1180 [0.9999989, 0.20000052]
# 1200 [0.9999989, 0.20000052]
# 1220 [0.9999989, 0.20000052]
# 1240 [0.9999989, 0.20000052]
# 1260 [0.9999989, 0.20000052]
# 1280 [0.9999989, 0.20000052]
# 1300 [0.9999989, 0.20000052]
# 1320 [0.9999989, 0.20000052]
# 1340 [0.9999989, 0.20000052]
# 1360 [0.9999989, 0.20000052]
# 1380 [0.9999989, 0.20000052]
# 1400 [0.9999989, 0.20000052]
# 1420 [0.9999989, 0.20000052]
# 1440 [0.9999989, 0.20000052]
# 1460 [0.9999989, 0.20000052]
# 1480 [0.9999989, 0.20000052]
# 1500 [0.9999989, 0.20000052]
# 1520 [0.9999989, 0.20000052]
# 1540 [0.9999989, 0.20000052]
# 1560 [0.9999989, 0.20000052]
# 1580 [0.9999989, 0.20000052]
# 1600 [0.9999989, 0.20000052]
# 1620 [0.9999989, 0.20000052]
# 1640 [0.9999989, 0.20000052]
# 1660 [0.9999989, 0.20000052]
# 1680 [0.9999989, 0.20000052]
# 1700 [0.9999989, 0.20000052]
# 1720 [0.9999989, 0.20000052]
# 1740 [0.9999989, 0.20000052]
# 1760 [0.9999989, 0.20000052]
# 1780 [0.9999989, 0.20000052]
# 1800 [0.9999989, 0.20000052]
# 1820 [0.9999989, 0.20000052]
# 1840 [0.9999989, 0.20000052]
# 1860 [0.9999989, 0.20000052]
# 1880 [0.9999989, 0.20000052]
# 1900 [0.9999989, 0.20000052]
# 1920 [0.9999989, 0.20000052]
# 1940 [0.9999989, 0.20000052]
# 1960 [0.9999989, 0.20000052]
# 1980 [0.9999989, 0.20000052]
# 2000 [0.9999989, 0.20000052]
